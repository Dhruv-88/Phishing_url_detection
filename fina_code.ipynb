# %% [markdown]
# # loading dataset and peforming Descriptive analysis

# %%
from final_project_code import perform_descriptive_analysis 

df=perform_descriptive_analysis('https://raw.githubusercontent.com/Dhruv-88/Phishing_url_detection/refs/heads/main/Phising_dataset_predict.csv')
# Out:
# loaded data sucessfully
# DataFrame Size: 8613683
# DataFrame Shape: (662591, 13)
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662591 entries, 0 to 662590
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          662591 non-null  int64
#  1   NumDots             662591 non-null  int64
#  2   UrlLength           662591 non-null  int64
#  3   AtSymbol            662591 non-null  int64
#  4   NumDash             662591 non-null  int64
#  5   NumPercent          662591 non-null  int64
#  6   NumQueryComponents  662591 non-null  int64
#  7   IpAddress           662591 non-null  int64
#  8   HttpsInHostname     662591 non-null  int64
#  9   PathLevel           662591 non-null  int64
#  10  PathLength          662591 non-null  int64
#  11  NumNumericChars     662591 non-null  int64
#  12  Phising             630071 non-null  float64
# ...

# %% [markdown]
# # Peforming EDA

# %%
from final_project_code import perform_eda 

df=perform_eda(df)
# Out:
# Missing values per column after dropping nulls:
# NumDots               0
# UrlLength             0
# AtSymbol              0
# NumDash               0
# NumPercent            0
# NumQueryComponents    0
# IpAddress             0
# HttpsInHostname       0
# PathLevel             0
# PathLength            0
# NumNumericChars       0
# Phising               0
# dtype: int64
# Displayed distribution of URL Length.
# Displayed distribution of log-transformed URL Length.
# Displayed distribution and box plot of Path Length.
# Original DataFrame shape: (630058, 13)
# DataFrame shape after dropping outliers: (630058, 13)
# Displayed box plot of Path Length after dropping outliers.
# Displayed log-transformed distribution of Path Length.
# Displayed scatter plot between URL Length and Path Length.
# Displayed heatmap of the correlation matrix.

# %% [markdown]
# # Applying machine learning algorithms

# %%
from final_project_code import apply_machine_learning 

apply_machine_learning(df)
# Out:
# Logistic Regression - Accuracy: 0.6996047430830039, Precision: 0.32119293746828004, Recall: 0.8017402320309375
# K-Nearest Neighbors - Accuracy: 0.8840738447862596, Precision: 0.6758272818193678, Recall: 0.5181357514335244
# Naive Bayes - Accuracy: 0.8495060611351863, Precision: 0.6501739466563587, Recall: 0.11214828643819176
# Decision Tree - Accuracy: 0.8905820912106925, Precision: 0.728078335373317, Recall: 0.49576610214695294
# Random Forest - Accuracy: 0.8317433105280145, Precision: 0.4822954103576268, Recall: 0.8187091612214962
#                  Model  Accuracy  Precision    Recall
# 0  Logistic Regression  0.699605   0.321193  0.801740
# 1  K-Nearest Neighbors  0.884074   0.675827  0.518136
# 2          Naive Bayes  0.849506   0.650174  0.112148
# 3        Decision Tree  0.890582   0.728078  0.495766
# 4        Random Forest  0.831743   0.482295  0.818709
# Displayed scatter plot between Accuracy and Precision.

# %% [markdown]
# # Evaluating results of best model

# %%
from final_project_code import evaluate_best_model

evaluate_best_model(df)
# Out:
# Random Forest Train Accuracy: 0.9133
# Random Forest Test Accuracy: 0.8951
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.97      0.94    158995
#          1.0       0.75      0.51      0.60     29996
#
#     accuracy                           0.90    188991
#    macro avg       0.83      0.74      0.77    188991
# weighted avg       0.89      0.90      0.89    188991
#
# Model saved successfully!
